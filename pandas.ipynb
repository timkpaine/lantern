# %%
from analytics.data import getTsData

# %%
import pandas as pd
pd.set_option('max_colwidth', 100)
x = getTsData(10)
x
# Out:
#              Series 0   Series 1   Series 2   Series 3   Series 4   Series 5  \
# 2014-12-14  -0.744811   0.744811   0.744811   0.744811  -0.744811   0.744811
# 2014-12-15  -0.321020   1.310781   0.079918   1.505326  -0.569294   0.589314
# 2014-12-16  -0.380498   1.167046   0.849175   1.113324   0.423937   0.753831
# 2014-12-17   0.505178   1.379198   0.850254   1.350606   0.628359   1.020346
# 2014-12-18   0.938915   1.260108   0.726434   2.008270   0.792574   0.378408
# 2014-12-19   1.332615   0.272902   0.480848   2.176128   1.237785   1.018213
# 2014-12-20   1.142864   0.173600  -0.301716   3.147537   1.816372   0.828667
# 2014-12-21   0.960240   0.596782  -1.191769   3.634227   1.648856  -0.030846
# 2014-12-22   1.640513   0.331276  -1.404910   3.010168   1.612007  -0.786180
# 2014-12-23   0.781163   0.134216  -1.648511   2.864882   1.062552  -0.821165
# 2014-12-24   0.489396  -0.657018  -1.248004   3.459406   1.690229  -1.541519
# ...

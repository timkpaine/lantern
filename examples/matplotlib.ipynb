# %%
# %%capture
import lantern as l

# %%
df = l.bar.sample()

# %%
col1 = df.columns[0]
col2 = df.columns[1]
df
# Out:
#               AIW.TU    HTX.NR    PLC.OL    IAL.WH    GVQ.WA
# 2015-01-01  0.773824 -0.032504 -0.767507  0.527401  0.621201
# 2015-01-02  1.820786 -0.247705 -1.796333  1.117004  1.204197
# 2015-01-03  0.089144 -0.661520 -1.540263  2.221108  1.887604
# 2015-01-04 -0.152475 -0.578092 -0.180255  1.596898  0.616223
# 2015-01-05 -0.354969  0.041663 -0.051348  3.083320  0.715465
# 2015-01-06 -0.759928 -1.391564  0.715328  2.363755 -1.221348
# 2015-01-07 -1.383492 -1.236581 -0.898227  1.342892  0.173756
# 2015-01-08 -0.102819 -1.237560 -0.955586  0.782602  0.563700
# 2015-01-09 -0.036542 -1.897957 -2.386082  1.115136 -0.637581
# 2015-01-10 -1.297052 -1.422930 -2.641337 -0.484417  0.216060

# %%
l.plot(df)

# %%
f = l.figure()
f.line(df[df.columns[:1]])
f.bar(df[df.columns[1:2]])
f.area(df[df.columns[1:2]])
f.show()

# %%
f = l.figure()
f.line(df[df.columns[:1]], y_axis='right')
f.bar(df[df.columns[1:2]])
f.area(df[df.columns[1:2]])
f.show()

# %%
# %%capture
import lantern as l

# %%
df = l.bar.sample()

# %%
col1 = df.columns[0]
col2 = df.columns[1]
df
# Out:
#               LCW.VB    PTO.CR    EXO.VH    KND.WX    JWC.FU
# 2015-01-01 -1.727846 -0.449599  1.283234 -0.359535  2.482592
# 2015-01-02 -2.880852 -0.256512  0.733482  1.512021  2.243434
# 2015-01-03 -1.663723  0.598550 -0.004088  1.677795  2.436296
# 2015-01-04 -0.558162 -0.060051  1.191973  2.358210  1.793385
# 2015-01-05 -0.369816  0.182589  1.662759  2.715605  2.711285
# 2015-01-06 -1.080638 -0.235638  1.719436  1.614420  2.435909
# 2015-01-07 -1.058613 -1.437937  2.524381  1.140053  1.613858
# 2015-01-08 -0.687182 -1.610061  2.933398  1.492558  1.708568
# 2015-01-09  0.365570 -1.125706  4.533042  0.830789  2.793094
# 2015-01-10  0.779528  0.017315  4.981752  0.526421  3.381039

# %%
l.plot(df)

# %%
f = l.figure()
f.line(df[df.columns[:1]])
f.bar(df[df.columns[1:2]])
f.area(df[df.columns[1:2]])
f.show()

# %%
f = l.figure()
f.line(df[df.columns[:1]], y_axis='right')
f.bar(df[df.columns[1:2]])
f.area(df[df.columns[1:2]], y_axis='right')
f.show()

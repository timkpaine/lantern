# %%
# %%capture
import lantern as l

# %%
df = l.bar.sample()

# %%
col1 = df.columns[0]
col2 = df.columns[1]

# %%
l.plot(df[[col1, col2]], size=(12,5), subplot=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-cde6d77e81a1> in <module>()
# ----> 1 l.plot(df[[col1, col2]], size=(12,5), subplot=True)
#
# /usr/local/lib/python3.7/site-packages/pylantern-0.0.20-py3.7.egg/lantern/plotting/__init__.py in plot(data, kind, backend, size, theme, **kwargs)
#      41     if isinstance(kind, str):
#      42         getattr(f, kind)(data, **kwargs)
# ---> 43         return f.show(**show_args)
#      44     elif isinstance(kind, list):
#      45         # TODO handle color, scatter, etc
#
# /usr/local/lib/python3.7/site-packages/pylantern-0.0.20-py3.7.egg/lantern/plotting/plot_matplotlib.py in show(self, title, xlabel, ylabel, xaxis, yaxis, xticks, yticks, legend, grid, **kwargs)
#     114             self._axes.remove(ax)
#     115
# --> 116         align_yaxis_np(self._axes)
#     117
#     118         for m in self._axes:
#
# /usr/local/lib/python3.7/site-packages/pylantern-0.0.20-py3.7.egg/lantern/plotting/plotutils.py in align_yaxis_np(axes)
#     104
#     105     # upper and lower limits
# --> 106     lowers = extrema[:, 0]
#     107     uppers = extrema[:, 1]
#     108
#
# IndexError: too many indices for array

# %%
f = l.figure()
f.line(df[df.columns[:1]])
f.bar(df[df.columns[1:2]])
f.area(df[df.columns[1:2]])
f.show()

# %%
f = l.figure()
f.line(df[df.columns[:1]], y_axis='right')
f.bar(df[df.columns[1:2]])
f.area(df[df.columns[1:2]], y_axis='right')
f.show(xticks=False)

# %%
l.plot(df, 'bar', 'matplotlib')

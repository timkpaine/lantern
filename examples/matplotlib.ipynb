# %%
# %%capture
import lantern as l

# %%
df = l.bar.sample()

# %%
col1 = df.columns[0]
col2 = df.columns[1]
df
# Out:
#               VFC.YE    VTG.VD    JFM.RF    AKA.OF    TUR.OI
# 2015-01-01 -1.586865  0.902944 -0.211797  0.293073 -2.063155
# 2015-01-02 -0.890799  0.088558 -0.923349  2.213226 -0.694011
# 2015-01-03 -2.126966  1.302231 -1.478534  2.668452 -2.029183
# 2015-01-04 -0.768368  0.746128 -1.386290  2.040165 -1.882220
# 2015-01-05  1.182179  0.409142 -1.632763  1.010487 -0.401283
# 2015-01-06  1.362238 -0.125723 -1.643009  1.363813 -0.387497
# 2015-01-07  2.869477  2.175066 -1.648217  2.740860  0.611631
# 2015-01-08  2.698023  2.616144 -0.178609  3.006106  0.734488
# 2015-01-09  2.690054  3.764522  0.938083  3.384055  1.090807
# 2015-01-10  4.210930  2.962789  0.246866  2.629916  1.264492

# %%
l.plot(df)

# %%
f = l.figure()
f.line(df[df.columns[:1]])
f.bar(df[df.columns[1:2]])
f.area(df[df.columns[1:2]])
f.show()

# %%
f = l.figure()
f.line(df[df.columns[:1]], y_axis='right')
f.bar(df[df.columns[1:2]])
f.area(df[df.columns[1:2]])
f.show()

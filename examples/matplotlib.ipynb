# %%
# %%capture
import lantern as l

# %%
df = l.bar.sample()

# %%
col1 = df.columns[0]
col2 = df.columns[1]
df
# Out:
#               FIQ.MA    HAU.PO    YWB.FY    NTY.PA    UOK.IV
# 2015-01-01  0.810661 -0.053816  0.026585 -0.336228 -0.234571
# 2015-01-02  0.226924 -1.287789  2.448354 -0.440775 -0.594146
# 2015-01-03  1.280767 -2.014911  3.376715 -2.648144 -2.249642
# 2015-01-04 -0.443935 -1.090186  2.643876 -2.756852 -2.368717
# 2015-01-05 -0.415889 -0.366389  2.645628 -1.600265 -2.265352
# 2015-01-06  0.294398  0.043625  1.952708 -2.116889 -2.734748
# 2015-01-07  1.116819 -1.523044  1.450297 -2.355915 -1.658728
# 2015-01-08  0.480219 -2.597690  2.518825 -2.849765 -2.778115
# 2015-01-09 -0.018565 -0.618765  2.945110 -4.096499 -1.827300
# 2015-01-10 -0.249410 -0.489283  2.216240 -3.170045 -1.415398

# %%
l.plot(df, size=(5,5))

# %%
f = l.figure()
f.line(df[df.columns[:1]])
f.bar(df[df.columns[1:2]])
f.area(df[df.columns[1:2]])
f.show()

# %%
f = l.figure()
f.line(df[df.columns[:1]], y_axis='right')
f.bar(df[df.columns[1:2]])
f.area(df[df.columns[1:2]], y_axis='right')
f.show()

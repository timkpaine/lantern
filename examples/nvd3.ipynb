# %%
# %%capture
import lantern as l

# %%
df = l.line()

# %%
col1 = df.columns[0]
col2 = df.columns[1]

# %%
l.plot(df[[col1, col2]], backend='d3')
# Out:
# <link media="all" href="files/nv.d3.css" type="text/css"
#                         rel="stylesheet"/>
# <script src="files/d3.v3.js"></script>
# <script src="files/nv.d3.js"></script>
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8" />
#         <link href="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.0/nv.d3.min.css" rel="stylesheet" />
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js"></script>
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.0/nv.d3.min.js"></script>
#     </head>
#     <body>
#
#     <div id="linechart"><svg style="width:700px;height:400px;"></svg></div>
#
#
#     <script>
#
#
#
# ...

# %%
l.plot(df, backend='d3')
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8" />
#         <link href="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.0/nv.d3.min.css" rel="stylesheet" />
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js"></script>
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.0/nv.d3.min.js"></script>
#     </head>
#     <body>
#
#     <div id="linechart"><svg style="width:700px;height:400px;"></svg></div>
#
#
#     <script>
#
#
#
# ...

# %%
df.index.astype(str).tolist()
# Out:
# ['2015-01-01',
#  '2015-01-02',
#  '2015-01-03',
#  '2015-01-04',
#  '2015-01-05',
#  '2015-01-06',
#  '2015-01-07',
#  '2015-01-08',
#  '2015-01-09',
#  '2015-01-10',
#  '2015-01-11',
#  '2015-01-12',
#  '2015-01-13',
#  '2015-01-14',
#  '2015-01-15',
#  '2015-01-16',
#  '2015-01-17',
#  '2015-01-18',
#  '2015-01-19',
#  '2015-01-20',
#  '2015-01-21',
#  '2015-01-22',
#  '2015-01-23',
#  '2015-01-24',
#  '2015-01-25',
#  '2015-01-26',
#  '2015-01-27',
#  '2015-01-28',
#  '2015-01-29',
#  '2015-01-30',
#  '2015-01-31',
#  '2015-02-01',
#  '2015-02-02',
#  '2015-02-03',
#  '2015-02-04',
#  '2015-02-05',
#  '2015-02-06',
#  '2015-02-07',
#  '2015-02-08',
#  '2015-02-09',
#  '2015-02-10',
#  '2015-02-11',
#  '2015-02-12',
#  '2015-02-13',
#  '2015-02-14',
#  '2015-02-15',
#  '2015-02-16',
#  '2015-02-17',
#  '2015-02-18',
#  '2015-02-19',
#  '2015-02-20',
#  '2015-02-21',
#  '2015-02-22',
#  '2015-02-23',
#  '2015-02-24',
#  '2015-02-25',
#  '2015-02-26',
#  '2015-02-27',
# ...

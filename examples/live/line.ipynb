# %%
import lantern.live as ll
from perspective.examples import line
# Out:
# Matplotlib loaded
# Plot.ly loaded
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="33117d50-5fb8-462a-abd9-a320a5fba516">Loading BokehJS ...</span>
#     </div>
# Qgrid loaded
# Perspective loaded
# Datagrid loaded

# %%
rs = ll.RandomSource2()
x = ll.run(rs)

# %%
line(x, 'close')
# Out:
# PerspectiveWidget(aggregates={'index': 'last', 'close': 'last'}, columnpivots=['key'], columns=['index', 'clos…

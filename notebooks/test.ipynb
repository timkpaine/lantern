# %%
import cufflinks as cf
cf.datagen.lines(50)
# Out:
#                YPJ.TM    TFJ.RS    ILE.PQ     ZDB.GN     NSM.GQ    LTF.II  \
# 2015-01-01  -0.638142 -0.689485  1.469053   0.046899  -0.660777  0.563914
# 2015-01-02   0.251586 -1.464217  2.170895  -0.308851  -1.389589  0.135378
# 2015-01-03   0.315154 -3.397635  0.490533   1.257519  -2.279287 -0.294648
# 2015-01-04  -0.757988 -4.425416  0.777377   1.625444  -2.899978  1.498950
# 2015-01-05  -0.141398 -4.632018 -0.283603   0.891939  -2.932504  3.053590
# 2015-01-06   0.884040 -5.550709 -0.281877   1.601610  -1.216600  3.621738
# 2015-01-07   1.017986 -3.707437 -1.068137   0.102747  -2.061128  1.732188
# 2015-01-08   0.611369 -3.866097 -0.021546   3.182279   0.229249  2.790955
# 2015-01-09   1.217398 -4.931117 -0.005736   3.603439   0.075544  3.926779
# 2015-01-10   1.045068 -4.067382  0.419556   3.895561  -1.241209  4.583262
# 2015-01-11   1.139137 -3.654637  2.159508   3.274740  -2.418141  3.860003
# 2015-01-12   0.902457 -3.166568  1.598278   1.985203  -3.504429  3.739384
# ...

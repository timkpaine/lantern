# %%
from analytics.data import getTsData

# %%
x = getTsData(4)

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.plot(x)
plt.show()

# %%
import seaborn as sns
sns.set_style('dark')
